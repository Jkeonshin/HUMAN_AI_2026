# %% [markdown]
# # 데이터 생성

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt   # 시각화 라이브러리 
import seaborn as sns
import plotly as px
import folium

# %%
# 날짜 생성
dates = pd.date_range('2024-01-01', '2024-12-31')

# 지역과 제품 카테고리 정의
regions = ['서울', '부산', '대구', '광주', '인천']
products = ['A', 'B', 'C', 'D']

# 가상의 매출데이터 생성 
data = {
    'date': np.random.choice(dates, 1000),
    'region': np.random.choice(regions, 1000),
    'product': np.random.choice(products, 1000),
    'sales': np.random.randint(100, 1000, 1000),    # 매출 100~1000만원
    'profit': np.random.randint(10, 200, 1000)       # 이익 10~200만원
}

# %%
df = pd.DataFrame(data)
df
# Out:
#           date region product  sales  profit
# 0   2024-03-11     대구       B    597      81
# 1   2024-06-11     서울       A    462     194
# 2   2024-10-05     서울       B    220      40
# 3   2024-09-15     인천       A    760     165
# 4   2024-07-16     인천       C    507      47
# ..         ...    ...     ...    ...     ...
# 995 2024-05-16     광주       A    959     143
# 996 2024-09-18     인천       D    286     189
# 997 2024-03-03     인천       C    377      49
# 998 2024-11-23     광주       A    637      61
# 999 2024-10-21     부산       D    565      47
#
# [1000 rows x 5 columns]

# %%
# csv 저장 
df.to_csv('./data/sales_data.csv',index=False, encoding='utf-8-sig')

# %%
! pip install plotly folium
# Out:
# Collecting plotly
#   Downloading plotly-6.9.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting folium
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting narwhals>=1.15.1 (from plotly)
#   Downloading narwhals-2.24.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging in d:\anaconda3\envs\ai\lib\site-packages (from plotly) (26.1)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: jinja2>=2.9 in d:\anaconda3\envs\ai\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in d:\anaconda3\envs\ai\lib\site-packages (from folium) (2.2.6)
# Requirement already satisfied: requests in d:\anaconda3\envs\ai\lib\site-packages (from folium) (2.34.2)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2026.3.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda3\envs\ai\lib\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda3\envs\ai\lib\site-packages (from requests->folium) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\ai\lib\site-packages (from requests->folium) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\anaconda3\envs\ai\lib\site-packages (from requests->folium) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\anaconda3\envs\ai\lib\site-packages (from requests->folium) (2026.7.22)
# Downloading plotly-6.9.0-py3-none-any.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ----------------------------- ---------- 7.3/9.9 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 40.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 21.3 MB/s  0:00:00
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.2-py3-none-any.whl (26 kB)
# Downloading narwhals-2.24.0-py3-none-any.whl (461 kB)
# Downloading xyzservices-2026.3.0-py3-none-any.whl (94 kB)
# Installing collected packages: xyzservices, narwhals, plotly, branca, folium
#
#    ---------------------------------------- 0/5 [xyzservices]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ---------------- ----------------------- 2/5 [plotly]
#    ------------------------ --------------- 3/5 [branca]
#    -------------------------------- ------- 4/5 [folium]
#    -------------------------------- ------- 4/5 [folium]
#    -------------------------------- ------- 4/5 [folium]
#    -------------------------------- ------- 4/5 [folium]
#    ---------------------------------------- 5/5 [folium]
#
# Successfully installed branca-0.8.2 folium-0.20.0 narwhals-2.24.0 plotly-6.9.0 xyzservices-2026.3.0

# %% [markdown]
# # 데이터 가져오기

# %%
# csv 불러오기 
df = pd.read_csv('./data/sales_data.csv') 
df['data']=pd.to_datetime(df['date']) #string 에서 datetime으로 타입 변경 
df.head()
# Out:
#          date region product  sales  profit       data
# 0  2024-03-11     대구       B    597      81 2024-03-11
# 1  2024-06-11     서울       A    462     194 2024-06-11
# 2  2024-10-05     서울       B    220      40 2024-10-05
# 3  2024-09-15     인천       A    760     165 2024-09-15
# 4  2024-07-16     인천       C    507      47 2024-07-16

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Seaborn

# %%
# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # 한글 폰트 지정
plt.rcParams['axes.unicode_minus'] = False

# %%
# 매출액(sales) 분포 히스토그램 -> 단일 변수의 분포 (빈도)를 시각적으로 파악 

plt.figure(figsize=(8, 5))

# %%
# 매출액(sales) 분포 히스토그램 -> 단일 변수의 분포 (빈도)를 시각적으로 파악 

plt.figure(figsize=(8, 5))                                        # 그래프의 사이즈 가로8 세로5
sns.histplot(df['sales'], bins=20, kde=True, color='royalblue')   # 그래프의 타입 (그리고자 하는 그래프의 종류 ) 사용할데이터 -> sales데이터

plt.title('매출액 분포 (histogram)', fontsize=14)                 # 제목 / 사이즈 
plt.xlabel('매출액(만원)')                                        # 매출액(만원)
plt.ylabel('빈도수')                                              # 빈도수

plt.show()

# %%
# 지역별 매출액 박스플롯을 통한 분포 비교 

plt.figure(figsize=(8,5))
sns.boxplot(x='region',y='sales', data=df, palette='Set2')

plt.title('지역별 매출액 분포 (BOX Plot)', fontsize=14)
plt.xlabel('지역')
plt.ylabel('매출액(만원)')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14228\4054640177.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='region',y='sales', data=df, palette='Set2')

# %%
# 지역별 매출액 박스플롯을 통한 분포 비교 

plt.figure(figsize=(8,5))
sns.violinplot(x='region',y='sales', data=df,inner='quartile',palette='muted')

plt.title('지역별 매출액 분포 (Violin Plot)', fontsize=14)
plt.xlabel('지역')
plt.ylabel('매출액(만원)')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14228\1955880633.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='region',y='sales', data=df,inner='quartile',palette='muted')

# %%
# 제품별 평균 매출 비교 (범주형 데이터의 평균/합계 비교)

plt.figure(figsize=(8, 5))

sns.barplot(x='product', y='sales', data=df, estimator=np.mean, errorbar='sd', palette='coolwarm')

plt.title('제품별 평균 매출 비교 (Bar Plot)', fontsize=14)
plt.xlabel('제품')
plt.ylabel('매출액(만원)')
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_14228\431722626.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='product', y='sales', data=df, estimator=np.mean, errorbar='sd', palette='coolwarm')

# %%
# 매출액(sales)과 이익(profit)의 상관관계 -> 두 연속형 변수 간의 관계 시각화 
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='sales', y='profit', hue='region', alpha=0.7) # hue는 지역별로 구분을 위해 색깔을 분기치라는 의미 

plt.title('매출-이익 관계(scatter plot)', fontsize=14)
plt.xlabel('매출액(만원)')
plt.ylabel('이익(만원)')
plt.show()

# %%
# 매출과 이익의 상관관계 히트맵 --> 여러 변수간의 상관계수를 색상으로 표현하는 목적의 그래프 

plt.figure(figsize=(5,4))
corr = df[['sales','profit']].corr()  # 상관계수 계산

sns.heatmap(corr, annot=True, cmap='Reds', vmin=-1, vmax=1)

plt.title('매출-이익 상관관계 히트맵', fontsize=14)
plt.show()

# %%
# 수치형 변수 간 전체 관계 탐색 -- 여러 변수의 조항 관계를 한번에 확인 
sns.pairplot(df[['sales','profit']],kind='scatter')

plt.suptitle('매출-이익 전체 관계 pairplot',y=1.02)
plt.show()

# %% [markdown]
# # Matplotlib

# %%
# date 컬럼을 datetime 타입으로 변환
df['date'] = pd.to_datetime(df['date'])

# 월별 총 매출 추세(시간 순서)

# 월 단위 매출 집계
df_month = df.groupby(df['date'].dt.to_period('M')).sum(numeric_only=True)
df_month.index = df_month.index.astype(str)

plt.figure(figsize=(8,5))
plt.plot(df_month.index, df_month['sales'], marker='o', color='royalblue')

plt.title('월별 총 매출 추세', fontsize=14)
plt.xlabel('월', fontsize=12)
plt.ylabel('매출액(만원)', fontsize=12)
plt.grid(True)

# x축 눈금 라벨 회전
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 지역별 평균 매출 비교 (donut chart)

region_sales = df.groupby('region')['sales'].sum()
colors = plt.cm.Pastel1(np.linspace(0,1,len(region_sales)))

fig, ax = plt.subplots(figsize=(7,7))
wedges, texts, autotexts = ax.pie(
    region_sales,
    labels=region_sales.index,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    pctdistance=0.8,
    wedgeprops=dict(width=0.4, edgecolor='w'))  # 도넛

ax.set_title('지역별 총 매출 비중(donut chart)', fontsize=14, fontweight='bold')
plt.show()

# %%
import plotly.io as pio

pio.renderers.default = "notebook_connected"

# %%
# 월별 + 지역별 총 매출 현황
import plotly.express as px
df['month'] = df['date'].dt.strftime('%Y-%m')
df_month_region = df.groupby(['month', 'region'])['sales'].sum().reset_index()

# plotly 그래프
fig = px.line(
    df_month_region,
    x='month',
    y='sales',
    color='region',
    title='지역별 월간 매출 추세',
    markers=True)

fig.update_layout(
    xaxis_title='월',
    yaxis_title='매출액(만원)',
    legend_title='지역')

fig.show()
# Out:
# <div style="height:525px; width:100%;">            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="f7bfce10-8540-40ea-a9c6-3166e02d01b5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f7bfce10-8540-40ea-a9c6-3166e02d01b5")) {                    Plotly.newPlot(                        "f7bfce10-8540-40ea-a9c6-3166e02d01b5",                        [{"hovertemplate":"region=\uad11\uc8fc\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uad11\uc8fc","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\uad11\uc8fc","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12"],"xaxis":"x","y":{"dtype":"i2","bdata":"4RZ5HEMhDiIGLG4j7jPiJnQeYR8mJCI9"},"yaxis":"y","type":"scatter"},{"hovertemplate":"region=\ub300\uad6c\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ub300\uad6c","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ub300\uad6c","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12"],"xaxis":"x","y":{"dtype":"i2","bdata":"QSaNKEQzeiEIHd4jsh11L0Yw8SykJF0t"},"yaxis":"y","type":"scatter"},{"hovertemplate":"region=\ubd80\uc0b0\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\ubd80\uc0b0","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\ubd80\uc0b0","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12"],"xaxis":"x","y":{"dtype":"i2","bdata":"VyO8LJUe4BrGLPwMKC6oIzUrdCG9GbIQ"},"yaxis":"y","type":"scatter"},{"hovertemplate":"region=\uc11c\uc6b8\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc11c\uc6b8","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\uc11c\uc6b8","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12"],"xaxis":"x","y":{"dtype":"i2","bdata":"2R0xGA4lxBnDFBgryzF6IKEehCHoJK0d"},"yaxis":"y","type":"scatter"},{"hovertemplate":"region=\uc778\ucc9c\u003cbr\u003emonth=%{x}\u003cbr\u003esales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\uc778\ucc9c","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"\uc778\ucc9c","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12"],"xaxis":"x","y":{"dtype":"i2","bdata":"cCmRErkh3hseNC8qvyrHN0ooxRp+H+Qe"},"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c ...

# %%
# 지역별 평균 매출 지도 시각화(Folium)

# 지역별 평균 매출 
region_sales = df.groupby('region')['sales'].mean()

# 지역별 위도/경도 좌표 정의 
region_coords = {
    '서울': [37.5665,126.9780],
    '부산': [35.1796,129.0756],
    '대구': [35.8714,128.6014],
    '광주': [35.1595,126.8526],
    '인천': [37.4563,126.7052]
}

# 지도 생성
m = folium.Map(location=[36.5, 127.8], zoom_start=7)

# 각 지역에 CircleMarker 추가
for region, avg_sales in region_sales.items():
    folium.CircleMarker(
        location=region_coords[region],
        radius=avg_sales / 50,  # 매출 크기에 비례한 원 크기
        color='blue',
        fill=True,
        fill_opacity=0.6,
        popup=f"{region}: {avg_sales:.1f}만원"
    ).add_to(m)

# 지도 저장 및 표시
m.save('sales_map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e197c6262d3c7ae158546b2e3bfc885a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e197c6262d3c7ae158546b2e3bfc885a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e197c6262d3c7ae158546b2e3bfc885a = L.map(
#                 &quot;map_e197c6262d3c7ae158546b2e3bfc885a&quot;,
#                 {
#                     center: [36.5, 127.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1695fbd290e19bf032341ff8e4618aca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1695fbd290e19bf032341ff8e4618aca.addTo(map_e197c6262d3c7ae158546b2e3bfc885a);
#
#
#             var circle_marker_a041b62e7acf6d2c5186ac384aecb20d = L.circleMarker(
#                 [35.1595, 126.8526],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.30049261083744, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e197c6262d3c7ae158546b2e3bfc885a);
#
#
#         var popup_3f230f5e83b482415579df5f07711d7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_271b0c696f1b3f2430f34eb5146e2cfd = $(`&lt;div id=&quot;html_271b0c696f1b3f2430f34eb5146e2cfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;광주: 565.0만원&lt;/div&gt;`)[0];
#                 popup_3f230f5e83b482415579df5f07711d7b.setContent(html_271b0c696f1b3f2430f34eb5146e2cfd);
#
#
#
#         circle_marker_a041b62e7acf6d2c5186ac384aecb20d.bindPopup(popup_3f230f5e83b482415579df5f07711d7b)
#         ;
#
#
#
#
#             var circle_marker_aab2f13bc9380de01fb4e58e2b9a708b = L.circleMarker(
#                 [35.8714, 128.6014],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.450139534883721, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e197c6262d3c7ae158546b2e3bfc885a);
#
#
#         var popup_4d98e2d3bc903049bc4467a44e34c510 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3bb4d77da40ecf06cae636fca689775 = $(`&lt;div id=&quot;html_b3bb4d77da40ecf06cae636fca689775&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;대구: 572.5만원&lt;/div&gt;`)[0];
#                 popup_4d98e2d3bc903049bc4467a44e34c510.setContent(html_b3bb4d77da40ecf06cae636fca689775);
#
#
#
#         circle_marker_aab2f13bc9380de01fb4e58e2b9a708b.bindPopup(popup_4d98e2d3bc903049bc4467a44e34c510)
#         ;
#
#
#
#
#             var circle_marker_01363ac6824fec5b82acad7aece687de = L.circleMarker(
#                 [35.1796, 129.0756],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.964972972972973, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e197c6262d3c7ae158546b2e3bfc885a);
#
#
#         var popup_cc5f22bf80c212e29077717723bf24da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ee7411b40d56d0dcfdfdb8fdc469d30 = $(`&lt;div id=&quot;html_1ee7411b40d56d0dcfdfdb8fdc469d30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;부산: 548.2만원&lt;/div&gt;`)[0];
#                 popup_cc5f22bf80c212e29077717723bf24da.setContent(html_1ee7411b40d56d0dcfdfdb8fdc469d30);
#
#
#
#         circle_marker_01363ac6824fec5b82acad7aece687de.bindPopup(popup_cc5f22bf80c212e29077717723bf24da)
#         ;
#
#
#
#
#             var circle_marker_076d35b0d3ac8321d9c450
